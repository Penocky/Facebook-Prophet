# %%
import pandas as pd
from fbprophet import Prophet
from matplotlib import pyplot as plt

# %% [markdown]
# # Modeling Holidays and Special Events

# %%
#import sample manning data
df = pd.read_csv('data/example_wp_log_peyton_manning.csv')
df.head()
# Out:
#            ds         y
# 0  2007-12-10  9.590761
# 1  2007-12-11  8.519590
# 2  2007-12-12  8.183677
# 3  2007-12-13  8.072467
# 4  2007-12-14  7.893572

# %%
m = Prophet()
m.fit(df)
future = m.make_future_dataframe(periods=366)
# Out:
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\pchen4\AppData\Local\Continuum\anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
# create a dataframe that includes the dates of all of Peyton Manning’s playoff appearances
#lower window, upper window: set additonal date
playoffs = pd.DataFrame({
  'holiday': 'playoff',
  'ds': pd.to_datetime(['2008-01-13', '2009-01-03', '2010-01-16',
                        '2010-01-24', '2010-02-07', '2011-01-08',
                        '2013-01-12', '2014-01-12', '2014-01-19',
                        '2014-02-02', '2015-01-11', '2016-01-17',
                        '2016-01-24', '2016-02-07']),
  'lower_window': 0,
  'upper_window': 1,
})
superbowls = pd.DataFrame({
  'holiday': 'superbowl',
  'ds': pd.to_datetime(['2010-02-07', '2014-02-02', '2016-02-07']),
  'lower_window': 0,
  'upper_window': 1,
})
holidays = pd.concat((playoffs, superbowls))

# %%
holidays.head()
# Out:
#    holiday         ds  lower_window  upper_window
# 0  playoff 2008-01-13             0             1
# 1  playoff 2009-01-03             0             1
# 2  playoff 2010-01-16             0             1
# 3  playoff 2010-01-24             0             1
# 4  playoff 2010-02-07             0             1

# %%
# create new Prophet object and pass in the historical dataframe
m = Prophet(holidays=holidays)
forecast = m.fit(df).predict(future)
# Out:
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\pchen4\AppData\Local\Continuum\anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
forecast[(forecast['playoff'] + forecast['superbowl']).abs() > 0][
        ['ds', 'playoff', 'superbowl']][-10:]
# Out:
#              ds   playoff  superbowl
# 2190 2014-02-02  1.224102   1.197251
# 2191 2014-02-03  1.912033   1.459945
# 2532 2015-01-11  1.224102   0.000000
# 2533 2015-01-12  1.912033   0.000000
# 2901 2016-01-17  1.224102   0.000000
# 2902 2016-01-18  1.912033   0.000000
# 2908 2016-01-24  1.224102   0.000000
# 2909 2016-01-25  1.912033   0.000000
# 2922 2016-02-07  1.224102   1.197251
# 2923 2016-02-08  1.912033   1.459945

# %%
fig = m.plot_components(forecast)

# %% [markdown]
# # Fourier Order for Seasonalities

# %%
from fbprophet.plot import plot_yearly
m = Prophet().fit(df)
a = plot_yearly(m)
# Out:
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\pchen4\AppData\Local\Continuum\anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
m = Prophet(yearly_seasonality=20).fit(df)
a = plot_yearly(m)
# Out:
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\pchen4\AppData\Local\Continuum\anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %% [markdown]
# # Specifying Custom Seasonalities

# %%
# replace weekly seasonality with mothly seasonality
m = Prophet(weekly_seasonality=False)
m.add_seasonality(name='monthly', period=30.5, fourier_order=5)
forecast = m.fit(df).predict(future)
fig = m.plot_components(forecast)
# Out:
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\pchen4\AppData\Local\Continuum\anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %% [markdown]
# # Prior scale for holidays and seasonality

# %%
# fix holiday overfitting issue by adjusting prior scale to smooth them
m = Prophet(holidays=holidays, holidays_prior_scale=0.05).fit(df)
forecast = m.predict(future)
forecast[(forecast['playoff'] + forecast['superbowl']).abs() > 0][
    ['ds', 'playoff', 'superbowl']][-10:]
# Out:
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\pchen4\AppData\Local\Continuum\anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
#              ds   playoff  superbowl
# 2190 2014-02-02  1.205038   0.969811
# 2191 2014-02-03  1.854391   0.986626
# 2532 2015-01-11  1.205038   0.000000
# 2533 2015-01-12  1.854391   0.000000
# 2901 2016-01-17  1.205038   0.000000
# 2902 2016-01-18  1.854391   0.000000
# 2908 2016-01-24  1.205038   0.000000
# 2909 2016-01-25  1.854391   0.000000
# 2922 2016-02-07  1.205038   0.969811
# 2923 2016-02-08  1.854391   0.986626

# %%
m = Prophet()
m.add_seasonality(
    name='weekly', period=7, fourier_order=3, prior_scale=0.1)

# %% [markdown]
# # Add Regressor

# %%
#add additional effect on Sundays during the NFL season
def nfl_sunday(ds):
    date = pd.to_datetime(ds)
    if date.weekday() == 6 and (date.month > 8 or date.month < 2):
        return 1
    else:
        return 0
df['nfl_sunday'] = df['ds'].apply(nfl_sunday)

m = Prophet()
m.add_regressor('nfl_sunday')
m.fit(df)

future['nfl_sunday'] = future['ds'].apply(nfl_sunday)

forecast = m.predict(future)
fig = m.plot_components(forecast)
# Out:
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\pchen4\AppData\Local\Continuum\anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
